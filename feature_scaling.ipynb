# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.utils import check_random_state
import pickle
import math

# %%
df = pd.read_csv("/content/drive/MyDrive/Data Science Project/sample_numeric_data_21_M.csv")
df.head()
# Out:
#    rating        asin parent_asin                       user_id  helpful_vote  \
# 0     5.0  B074J5WVYH  B0759B7KLH  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ             0
# 1     5.0  B079TRNVHX  B079TRNVHX  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ             1
# 2     5.0  B07194LN2Z  B07194LN2Z  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ             0
# 3     5.0  B005CD4196  B005CD4196  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ             7
# 4     5.0  B07R2X568B  B0BG8M4XW7  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ             0
#
#    verified_purchase  sentiment    month  polarity  subjectivity  text_length  \
# 0                  1          2  2020-04  0.550000      0.750000           71
# 1                  1          2  2020-04  0.408333      0.612821          258
# 2                  1          2  2020-02  0.500000      1.000000            8
# 3                  1          2  2020-02  0.800000      0.750000           34
# 4                  1          1  2020-02  0.000000      0.000000           11
#
#    previous_rating  cluster
# ...

# %%
df = df.drop(['asin', 'parent_asin', 'user_id', 'cluster', 'month'], axis=1)

# %%
df.shape
# Out:
# (21640854, 8)

# %%
class_distribution = df['sentiment'].value_counts()
print(class_distribution)
# Out:
# sentiment
# 2    17065254
# 0     2449911
# 1     2125689
# Name: count, dtype: int64

# %%
undersampled_df = df.groupby('sentiment').sample(n=2125689, random_state=42)
print(undersampled_df)
# Out:
#           rating  helpful_vote  verified_purchase  sentiment  polarity  \
# 8219308      1.0             4                  1          0 -0.023333
# 12588514     2.0             4                  1          0 -0.110417
# 7487960      1.0             0                  1          0 -0.468750
# 6807300      1.0             0                  1          0 -1.000000
# 2140222      3.0             0                  1          0 -0.062500
# ...          ...           ...                ...        ...       ...
# 7646601      5.0             2                  1          2  0.291667
# 5037587      5.0             0                  1          2  0.350000
# 8348965      5.0             1                  1          2  0.544444
# 7862924      5.0             0                  1          2  0.500000
# 11808391     5.0             0                  1          2  0.442500
#
#           subjectivity  text_length  previous_rating
# 8219308       0.723333          174              1.0
# ...

# %%
undersampled_df.head()
# Out:
#           rating  helpful_vote  verified_purchase  sentiment  polarity  \
# 8219308      1.0             4                  1          0 -0.023333
# 12588514     2.0             4                  1          0 -0.110417
# 7487960      1.0             0                  1          0 -0.468750
# 6807300      1.0             0                  1          0 -1.000000
# 2140222      3.0             0                  1          0 -0.062500
#
#           subjectivity  text_length  previous_rating
# 8219308       0.723333          174              1.0
# 12588514      0.431250          138              5.0
# 7487960       0.625000           60              1.0
# 6807300       1.000000           14              5.0
# 2140222       0.588889           33              5.0

# %%
undersampled_df.shape
# Out:
# (6377067, 8)

# %%
class_distribution = undersampled_df['sentiment'].value_counts()
print(class_distribution)
# Out:
# sentiment
# 0    2125689
# 1    2125689
# 2    2125689
# Name: count, dtype: int64

# %%
train_df, test_df = train_test_split(undersampled_df, test_size=0.1, random_state=42)

# %%
train_df.to_csv('/content/drive/MyDrive/Data Science Project/processed_train_dataset.csv')
test_df.to_csv('/content/drive/MyDrive/Data Science Project/processed_test_dataset.csv')

# %%
train_df.head()
# Out:
#           rating  helpful_vote  verified_purchase  sentiment  polarity  \
# 6384908      1.0             0                  1          1  0.000000
# 9567116      5.0            13                  1          1  0.000000
# 5749535      5.0             0                  1          2  1.000000
# 15464359     3.0             0                  1          1  0.000000
# 12386221     5.0             0                  1          2  0.357143
#
#           subjectivity  text_length  previous_rating
# 6384908       0.000000           39              5.0
# 9567116       0.000000          186              1.0
# 5749535       0.300000            4              5.0
# 15464359      0.333333           82              1.0
# 12386221      0.728571          122              2.0

# %%
test_df.head()
# Out:
#           rating  helpful_vote  verified_purchase  sentiment  polarity  \
# 10713074     5.0             0                  1          1       0.0
# 7865882      5.0             0                  1          1       0.0
# 8856127      1.0             0                  1          0      -0.1
# 10733842     3.0             0                  1          1       0.0
# 13702628     5.0             0                  1          2       0.5
#
#           subjectivity  text_length  previous_rating
# 10713074           0.0           42              5.0
# 7865882            0.0           32              5.0
# 8856127            0.4           19              5.0
# 10733842           0.0           24              5.0
# 13702628           0.6           22              1.0

# %%
train_df.shape, test_df.shape
# Out:
# ((5739360, 8), (637707, 8))

# %%
sentiment = np.array(list(df['sentiment']))

# %%
train_df = train_df.drop(["sentiment"], axis=1)

# %%
train_df.head()
# Out:
#           rating  helpful_vote  verified_purchase  polarity  subjectivity  \
# 6384908      1.0             0                  1  0.000000      0.000000
# 9567116      5.0            13                  1  0.000000      0.000000
# 5749535      5.0             0                  1  1.000000      0.300000
# 15464359     3.0             0                  1  0.000000      0.333333
# 12386221     5.0             0                  1  0.357143      0.728571
#
#           text_length  previous_rating
# 6384908            39              5.0
# 9567116           186              1.0
# 5749535             4              5.0
# 15464359           82              1.0
# 12386221          122              2.0

# %%
train_df.shape
# Out:
# (5739360, 7)

# %%
train_data = train_df.iloc[:,:].values

# %%
scaler = StandardScaler()
train_data_scaled = scaler.fit_transform(train_data)

# %%
train_data_scaled.shape
# Out:
# (5739360, 7)

# %%
def bernstein_inequality(n, epsilon, delta):
    return math.ceil((4 * n * np.log(1 / delta)) / (epsilon ** 2))

# %%
k = 5
epsilon = 0.99
delta = 0.99

# %%
n_s = bernstein_inequality(5739360, epsilon, delta)
print(n_s)
# Out:
# 235415

# %%
def compute_coreset(X, coreset_size, random_state=None):
    n_samples, _ = X.shape
    random_state = check_random_state(random_state)
    mean = np.mean(X, axis=0)
    distances = np.sum((X - mean) ** 2, axis=1)
    sensitivities = distances / np.sum(distances)
    # sensitivities += 1 / n_samples
    # sensitivities /= np.sum(sensitivities)
    sampled_indices = random_state.choice(np.arange(n_samples), size=coreset_size, replace=False, p=sensitivities)
    coreset_X = X[sampled_indices]
    coreset_weights = 1 / (coreset_size * sensitivities[sampled_indices])
    return coreset_X, coreset_weights

# %%
np.random.seed(42)
coreset_size = 235415
train_coreset, train_coreset_weights = compute_coreset(train_data_scaled, coreset_size, random_state=42)

# %%
train_coreset.shape
# Out:
# (235415, 7)

# %%
train_coreset_weights.shape
# Out:
# (235415,)

# %%
coreset_dict = {"coreset_matrix":train_coreset, 'weights':train_coreset_weights}

# %%
with open('/content/drive/MyDrive/Data Science Project/coresets_train_dataset.pkl', 'wb') as file:
    pickle.dump(coreset_dict, file)

# %%
sentiments = np.array(list(test_df['sentiment']))

# %%
test_df = test_df.drop(['sentiment'],axis=1)
test_df.head()
# Out:
#           rating  helpful_vote  verified_purchase  polarity  subjectivity  \
# 10713074     5.0             0                  1       0.0           0.0
# 7865882      5.0             0                  1       0.0           0.0
# 8856127      1.0             0                  1      -0.1           0.4
# 10733842     3.0             0                  1       0.0           0.0
# 13702628     5.0             0                  1       0.5           0.6
#
#           text_length  previous_rating
# 10713074           42              5.0
# 7865882            32              5.0
# 8856127            19              5.0
# 10733842           24              5.0
# 13702628           22              1.0

# %%
test_df.shape
# Out:
# (637707, 7)

# %%
test_data = test_df.iloc[:,:].values

# %%
scaler = StandardScaler()
test_data_scaled = scaler.fit_transform(test_data)

# %%
test_set_dict = {"data":test_data_scaled, 'labels':sentiments}

# %%
with open('/content/drive/MyDrive/Data Science Project/coresets_test_dataset.pkl', 'wb') as file:
    pickle.dump(test_set_dict, file)

# %%
sample_test_set_dict = {"data":test_data_scaled[:10], 'labels':sentiments[:10]}

# %%
with open('/content/drive/MyDrive/Data Science Project/sample_coresets_test_dataset.pkl', 'wb') as file:
    pickle.dump(sample_test_set_dict, file)
